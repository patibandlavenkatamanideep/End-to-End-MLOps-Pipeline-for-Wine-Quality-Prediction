# %%
d = {"key":"value", "key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"value", "key1":"value1"})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=4)
# Out:
# 8

# %%
get_prodict(x=2, y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=4)
# Out:
# 8

# %%
get_prodict(x=2, y="4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_prodict(x=2, y="4")
#
# File ~/Documents/GitHub/MLOps/End-to-End-MLOps-Pipeline-for-Wine-Quality-Prediction/.venv/lib/python3.14/site-packages/ensure/main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x10b536b90> does not match annotation type <class 'int'>
